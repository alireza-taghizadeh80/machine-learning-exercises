# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

# %%
data = pd.read_csv('linear_health_dataset.csv')

# %%
data
# Out:
#      Age  Gender   Education Smoking  Activity        BMI      Waist  \
# 0     56    Male  HighSchool      No       Low  28.220249  78.908910
# 1     69    Male    Bachelor     Yes       Low  23.796130  65.401435
# 2     46  Female  HighSchool      No       Low  28.121568  76.417668
# 3     32    Male  HighSchool      No  Moderate  28.448161  78.768517
# 4     60    Male    Bachelor      No       Low  27.573376  67.421361
# ..   ...     ...         ...     ...       ...        ...        ...
# 995   18    Male  HighSchool      No      High  28.634908  85.904316
# 996   35  Female      Master      No       Low  34.319839  87.182092
# 997   49  Female  HighSchool      No       Low  27.448266  86.804165
# 998   64    Male  HighSchool      No       Low  31.566515  82.327263
# 999   66  Female    Bachelor     Yes       Low  25.231380  74.096282
#
#            HDL  Triglycerides  MetabolicRiskScore
# 0    48.996843     233.136570          116.847116
# 1    50.834187     164.496459          118.518046
# 2    34.598058     145.768476           93.899151
# 3    65.125676     199.542320           95.023080
# 4    53.910602      91.924653           66.894203
# ..         ...            ...                 ...
# 995  52.179185     196.883446          104.839808
# 996  25.611334     171.222801          111.251640
# 997  35.691047      89.383815           92.915192
# 998  38.181466     145.154047          110.838767
# 999  47.008570     207.541031          128.700946
#
# [1000 rows x 10 columns]

# %%
x = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %%
print(np.unique(x[:,4]))
# Out:
# ['High' 'Low' 'Moderate']

# %%
activity_order = [['Low', 'Moderate', 'High']]
education_order = [['HighSchool', 'Bachelor', 'Master', 'PhD']]
smoking_order = [['No', 'Yes']]

# %%
ct = ColumnTransformer(transformers= [('gender_ohe', OneHotEncoder(drop='first'), [1]), 
                                      ('activity_ord', OrdinalEncoder(categories=activity_order), [4]), 
                                      ('edu_ord', OrdinalEncoder(categories=education_order), [2]),
                                      ('smok_ord', OrdinalEncoder(categories=smoking_order), [3])], remainder= 'passthrough')

# %%
x = ct.fit_transform(x)

# %%
x.shape
# Out:
# (1000, 9)

# %%
x[:5]
# Out:
# array([[1.0, 0.0, 0.0, 0.0, 56, 28.220248555860667, 78.90891022566693,
#         48.99684285969641, 233.13656956057565],
#        [1.0, 0.0, 1.0, 1.0, 69, 23.79612961241608, 65.40143518720694,
#         50.83418748440542, 164.49645851501805],
#        [0.0, 0.0, 0.0, 0.0, 46, 28.121567884453256, 76.41766751838377,
#         34.59805837191012, 145.7684759174094],
#        [1.0, 1.0, 0.0, 0.0, 32, 28.44816058343621, 78.76851736312292,
#         65.12567554823671, 199.54231984622592],
#        [1.0, 0.0, 1.0, 0.0, 60, 27.57337553038356, 67.42136079952805,
#         53.9106015602028, 91.92465297993007]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred))
# Out:
# 0.7345426483070929

# %%
np.set_printoptions(precision= 2)
print(np.concatenate((y_pred.reshape(len(y_pred), 1), y_test.reshape(len(y_test), 1)), 1))
# Out:
# [[ 58.73  79.94]
#  [ 98.23  70.75]
#  [ 70.69  68.36]
#  [100.14  91.58]
#  [ 73.82  69.95]
#  [ 93.76  94.  ]
#  [ 70.72  78.85]
#  [ 74.64  70.65]
#  [107.87  93.8 ]
#  [ 81.74  68.36]
#  [111.22 111.9 ]
#  [ 81.31  83.66]
#  [ 85.48  95.95]
#  [ 67.74  71.35]
#  [ 89.87  91.88]
#  [ 70.41  58.22]
#  [ 92.17  96.52]
#  [106.49 110.8 ]
#  [ 58.5   33.24]
#  [ 66.27  75.24]
#  [ 72.56  71.09]
#  [ 89.74  89.36]
#  [ 78.51  73.04]
#  [ 90.6  105.22]
#  [ 66.27  77.08]
#  [ 67.5   71.44]
#  [ 75.66  75.87]
#  [ 64.76  70.44]
#  [ 74.76  60.82]
#  [ 99.42  88.42]
#  [ 87.19  90.45]
#  [ 77.18  72.58]
#  [104.   103.96]
#  [101.79 102.09]
#  [ 86.85  95.2 ]
#  [ 83.07  77.76]
#  [ 85.06  84.47]
#  [ 76.41  77.13]
#  [103.94 109.65]
#  [103.72 107.48]
#  [ 73.93  60.06]
#  [102.8   82.2 ]
#  [ 49.64  50.89]
#  [ 85.65  78.09]
#  [ 68.16  71.98]
#  [ 86.42  84.94]
#  [129.39 126.19]
#  [ 58.15  69.66]
#  [ 94.79  81.68]
#  [ 85.93 104.84]
#  [ 66.59  88.97]
#  [106.58 127.55]
#  [ 46.65  48.46]
#  [125.03 136.22]
#  [ 89.86  97.83]
#  [ 96.42  89.87]
#  [ 65.27  63.71]
#  [110.29 108.35]
#  [107.1  112.34]
#  [ 66.94  75.42]
#  [112.81 110.63]
#  [ 98.63  97.12]
#  [ 70.48  70.46]
#  [ 78.22  71.74]
#  [112.77  98.88]
#  [ 95.74  92.96]
#  [ 98.36  86.58]
#  [ 95.45 116.24]
#  [ 45.73  39.16]
#  [ 99.83 107.71]
#  [ 68.81  71.13]
#  [ 74.33  73.61]
#  [ 71.77  61.3 ]
#  [ 72.87  59.15]
#  [ 67.79  71.78]
#  [ 81.9   76.99]
#  [ 77.29  63.41]
#  [ 82.35  85.03]
#  [ 92.62  99.31]
#  [ 75.33  53.57]
#  [ 91.31  85.14]
#  [ 52.72  46.28]
#  [ 60.19  33.95]
#  [ 45.94  42.91]
#  [118.01 117.47]
#  [ 91.62  76.35]
#  [ 75.12  55.34]
#  [ 95.81 113.8 ]
#  [ 64.23  80.53]
#  [ 80.67  83.22]
#  [ 76.57  84.1 ]
#  [ 77.48  83.32]
#  [ 98.55  97.15]
#  [112.41  93.27]
#  [ 61.5   41.07]
#  [ 87.87  78.73]
#  [ 84.27  86.46]
#  [ 94.04 102.06]
#  [116.09 100.61]
#  [ 89.66  79.42]
#  [ 69.82  65.85]
#  [ 67.88  72.02]
#  [ 94.94  91.54]
#  [ 86.75  87.27]
#  [ 59.17  35.36]
#  [ 84.02  82.39]
#  [ 57.24  38.79]
#  [ 74.55  58.28]
#  [ 76.74  94.15]
#  [ 75.2   91.47]
#  [ 72.44  44.58]
#  [ 80.67  69.7 ]
#  [ 84.92  84.  ]
#  [ 70.33  53.23]
#  [107.21 104.12]
#  [108.61  88.48]
#  [ 92.53  94.01]
#  [ 51.13  45.29]
#  [ 89.84 101.11]
#  [ 93.75 122.08]
#  [ 47.68  73.21]
#  [ 82.5   77.65]
#  [ 88.14  95.02]
#  [ 80.4   78.77]
#  [113.33 121.83]
#  [ 86.54  85.06]
#  [ 65.06  62.44]
#  [ 71.92  59.46]
#  [ 84.46  64.16]
#  [ 77.27  80.15]
#  [ 99.88  96.14]
#  [ 79.95  76.56]
#  [141.53 127.9 ]
#  [ 92.46  93.9 ]
#  [ 78.91  92.92]
#  [ 97.66  86.15]
#  [ 55.52  54.21]
#  [ 85.77  95.75]
#  [ 56.57  62.82]
#  [ 55.23  63.67]
#  [118.59 120.46]
#  [ 98.95 110.4 ]
#  [ 47.28  55.83]
#  [100.32  89.08]
#  [117.23 106.42]
#  [ 86.28  87.63]
#  [ 99.47  97.62]
#  [109.03 113.09]
#  [ 66.97  64.2 ]
#  [113.62 104.85]
#  [ 76.24  90.34]
#  [ 99.06  85.89]
#  [ 93.65  94.95]
#  [ 89.93  92.49]
#  [ 80.53  78.19]
#  [ 93.18  64.42]
#  [ 71.51  72.68]
#  [ 86.71  78.62]
#  [ 72.61  73.88]
#  [ 92.28  75.06]
#  [ 91.73  82.14]
#  [ 67.    58.79]
#  [ 86.73  75.18]
#  [ 83.52  85.42]
#  [127.15 121.3 ]
#  [ 95.61 111.82]
#  [ 80.49  92.34]
#  [106.92 102.08]
#  [ 81.84  67.43]
#  [ 75.18  89.17]
#  [ 77.57  64.36]
#  [ 66.36  63.95]
#  [103.19 109.98]
#  [ 30.87  30.62]
#  [119.89 127.46]
#  [129.4  130.71]
#  [ 77.66  96.61]
#  [ 67.99  69.41]
#  [ 66.37  53.1 ]
#  [112.23 105.9 ]
#  [ 70.31  69.11]
#  [ 74.73  83.2 ]
#  [ 80.97  80.42]
#  [ 95.49  95.32]
#  [ 75.03  68.4 ]
#  [103.17  99.01]
#  [ 72.65  72.1 ]
#  [ 78.87  73.88]
#  [ 63.51  55.29]
#  [ 71.42  55.71]
#  [ 86.32  98.51]
#  [ 89.91  88.12]
#  [ 70.83  67.68]
#  [ 46.91  54.9 ]
#  [ 66.31  61.38]
#  [ 86.96  80.6 ]
#  [ 93.43  72.67]
#  [105.92 109.63]
#  [ 43.84  46.9 ]
#  [ 60.3   62.1 ]]
